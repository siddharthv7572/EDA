# %%
import pandas as pd
df=pd.read_csv("Students.csv")
print(df)
# Out:
#    student_id    name department  math_score  science_score  attendance
# 0           1    Arun        CSE          78             74          92
# 1           2   Megha         AI          88             91          95
# 2           3    Raju         IT          56             63          85
# 3           4     Anu        CSE          92             89          98
# 4           5    Hari         AI          45             52          76
# 5           6    Sara         IT          67             71          88
# 6           7    John        CSE          81             69          90
# 7           8  Devika         AI          74             77          94
# 8           9  Nikhil         IT          59             58          80
# 9          10    Amal        CSE          85             83          96

# %%
df.head(5)
# Out:
#    student_id   name department  math_score  science_score  attendance
# 0           1   Arun        CSE          78             74          92
# 1           2  Megha         AI          88             91          95
# 2           3   Raju         IT          56             63          85
# 3           4    Anu        CSE          92             89          98
# 4           5   Hari         AI          45             52          76

# %%
avg_math=df['math_score'].mean()
avg_science=df['science_score'].mean()
print("math average marks",avg_math)
print("science average marks",avg_science)
# Out:
# math average marks 72.5
# science average marks 72.7

# %%
df[df['math_score']>80]
# Out:
#    student_id   name department  math_score  science_score  attendance
# 1           2  Megha         AI          88             91          95
# 3           4    Anu        CSE          92             89          98
# 6           7   John        CSE          81             69          90
# 9          10   Amal        CSE          85             83          96

# %%
df.sort_values(by='attendance',ascending=False)
# Out:
#    student_id    name department  math_score  science_score  attendance
# 3           4     Anu        CSE          92             89          98
# 9          10    Amal        CSE          85             83          96
# 1           2   Megha         AI          88             91          95
# 7           8  Devika         AI          74             77          94
# 0           1    Arun        CSE          78             74          92
# 6           7    John        CSE          81             69          90
# 5           6    Sara         IT          67             71          88
# 2           3    Raju         IT          56             63          85
# 8           9  Nikhil         IT          59             58          80
# 4           5    Hari         AI          45             52          76

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.barplot(x='name',y='math_score',data=df)
# Out:
# <Axes: xlabel='name', ylabel='math_score'>

# %%
plt.plot(df['name'], df['attendance'], marker='o')

# %%
plt.plot(df['name'], df['attendance'], marker='o')
plt.title("Attendance Trend")
plt.xlabel("Students")
plt.ylabel("Attendance")
plt.show()
