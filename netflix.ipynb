# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv(r'C:\Users\siddh\OneDrive\Desktop\aiml\pandas\netflix_titles.csv.csv')
df=df.head(10)
print(df.to_string())
# Out:
#   show_id     type                             title                       director                                                                                                                                                                                                                                                                                                             cast                                                                country          date_added  release_year rating   duration                                                      listed_in                                                                                                                                                description
# ...

# %%
sns.countplot(x='title',data=df)
# Out:
# <Axes: xlabel='title', ylabel='count'>

# %%
sns.jointplot(x='type',y='title',data=df,kind='scatter')

# %%
sns.countplot(x='type',data=df)
# Out:
# <Axes: xlabel='type', ylabel='count'>

# %%
sns.barplot(x='country',y='title',data=df)
# Out:
# <Axes: xlabel='country', ylabel='title'>

# %%
sns.histplot(df['country'],bins=20)
# Out:
# <Axes: xlabel='country', ylabel='Count'>
