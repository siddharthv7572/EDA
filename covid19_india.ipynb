# %%
import pandas as pd

covid19_india_df = pd.read_csv('covid19_india.csv')
covid19_india_df=covid19_india_df.head(50)#see only the first 50 rows without modifying the DataFrame
print(covid19_india_df.to_string())
# Out:
#     Sno        Date State/UnionTerritory  ConfirmedIndianNational  ConfirmedForeignNational  Cured  Deaths
# 0     1  30-01-2020               Kerala                        1                         1      0       0
# 1     2  31-01-2020               Kerala                        1                         0      0       0
# 2     3  01-02-2020               Kerala                        2                         0      0       0
# 3     4  02-02-2020               Kerala                        3                         0      0       0
# 4     5  03-02-2020               Kerala                        3                         0      0       0
# 5     6  04-02-2020               Kerala                        3                         0      0       0
# 6     7  05-02-2020               Kerala                        3                         0      0       0
# 7     8  06-02-2020               Kerala                        3                         0      0       0
# 8     9  07-02-2020               Kerala                        3                         0      0       0
# 9    10  08-02-2020               Kerala                        3                         0      0       0
# 10   11  09-02-2020               Kerala                        3                         0      0       0
# 11   12  10-02-2020               Kerala                        3                         0      0       0
# 12   13  11-02-2020               Kerala                        3                         0      0       0
# 13   14  12-02-2020               Kerala                        3                         0      0       0
# 14   15  13-02-2020               Kerala                        3                         0      0       0
# 15   16  14-02-2020               Kerala                        3                         0      0       0
# 16   17  15-02-2020               Kerala                        3                         0      0       0
# 17   18  16-02-2020               Kerala                        3                         0      0       0
# 18   19  17-02-2020               Kerala                        3                         0      0       0
# 19   20  18-02-2020               Kerala                        3                         0      0       0
# 20   21  19-02-2020               Kerala                        3                         0      0       0
# 21   22  20-02-2020               Kerala                        3                         0      0       0
# 22   23  21-02-2020               Kerala                        3                         0      0       0
# 23   24  22-02-2020               Kerala                        3                         0      0       0
# 24   25  23-02-2020               Kerala                        3                         0      0       0
# 25   26  24-02-2020               Kerala                        3                         0      0       0
# 26   27  25-02-2020               Kerala                        3                         0      0       0
# 27   28  26-02-2020               Kerala                        3                         0      0       0
# 28   29  27-02-2020               Kerala                        3                         0      0       0
# 29   30  28-02-2020               Kerala                        3                         0      0       0
# 30   31  29-02-2020               Kerala                        3                         0      0       0
# 31   32  01-03-2020               Kerala                        3                         0      0       0
# 32   33  02-03-2020            Telengana                        1                         0      0       0
# 33   34  02-03-2020               Kerala                        3                         0      0       0
# 34   35  02-03-2020                Delhi                        1                         0      0       0
# 35   36  03-03-2020            Telengana                        1                         0      0       0
# 36   37  03-03-2020            Rajasthan                        0                         1      0       0
# 37   38  03-03-2020               Kerala                        3                         0      3       0
# 38   39  03-03-2020                Delhi                        1                         0      0       0
# 39   40  04-03-2020        Uttar Pradesh                        6                         0      0       0
# 40   41  04-03-2020               Kerala                        3                         0      3       0
# 41   42  04-03-2020              Haryana                        0                         2      0       0
# 42   43  04-03-2020                Delhi                        1                         0      0       0
# 43   44  04-03-2020            Telengana                        1                         0      0       0
# 44   45  04-03-2020            Rajasthan                        1                         4      0       0
# 45   46  05-03-2020                Delhi                        2                         0      0       0
# 46   47  05-03-2020              Haryana                        0                         2      0       0
# 47   48  05-03-2020               Kerala                        3                         0      3       0
# 48   49  05-03-2020            Rajasthan                        1                         4      0       0
# 49   50  05-03-2020            Telengana                        1                         0      0       0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.histplot(covid19_india_df['State/UnionTerritory'],bins=20)#which state has more sick count
# Out:
# <Axes: xlabel='State/UnionTerritory', ylabel='Count'>

# %%
#cofirmed indan national and confirmed foreign national 
sns.jointplot(x='ConfirmedIndianNational',y='ConfirmedForeignNational',data=covid19_india_df,kind='reg')

# %%
#sns.jointplot(x='Date',y='',data=covid19_india_df,kind='kde',fill='true')

# %%
sns.pairplot(covid19_india_df,hue='State/UnionTerritory',palette='Reds',diag_kind='hist')

# %%
sns.barplot(x='ConfirmedIndianNational',y='ConfirmedForeignNational',data=covid19_india_df)
# Out:
# <Axes: xlabel='ConfirmedIndianNational', ylabel='ConfirmedForeignNational'>

# %%
covid19_india_df['TotalConfirmed'] = covid19_india_df['ConfirmedIndianNational'] + covid19_india_df['ConfirmedForeignNational']
sns.boxplot(x='Date',y='State/UnionTerritory',data=covid19_india_df.head(50),hue='TotalConfirmed')
plt.legend(loc=0)

# %%
#sns.countplot(x='State/UnionTerritory',data=covid19_india_df)

# %%
#plt.figure(figsize=(12,6))
#covid19_india_df['TotalConfirmed'] = covid19_india_df['ConfirmedIndianNational'] + covid19_india_df['ConfirmedForeignNational']

#sns.barplot(data=covid19_india_df, x='TotalConfirmed', y='State/UnionTerritory', palette='Reds_r')
